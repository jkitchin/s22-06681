# %% [markdown]
# Course schedule
# ===============

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-17 Mon] </span></span> NO CLASS - MLK Day

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-19 Wed] </span></span> [./00-introduction/00-introduction.ipynb](./00-introduction/00-introduction.ipynb)
