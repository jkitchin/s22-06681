# %% [markdown]
# Course schedule
# ===============

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-17 Mon] </span></span> NO CLASS - MLK Day

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-19 Wed] </span></span> Introduction [./00-introduction/introduction.ipynb](./00-introduction/introduction.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-24 Mon] </span></span> Review of numpy [./01-numpy/numpy.ipynb](./01-numpy/numpy.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-26 Wed] </span></span> Introduction to pandas [./02-pandas-intro/pandas-intro.ipynb](./02-pandas-intro/pandas-intro.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-01-31 Mon] </span></span> Intermediate pandas [./03-intermediate-pandas/intermediate-pandas.ipynb](./03-intermediate-pandas/intermediate-pandas.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-02 Wed] </span></span> pandas database [./04-pandas-database/pandas-database.ipynb](./04-pandas-database/pandas-database.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-07 Mon] </span></span> Linear regression [./05-linear-regression/linear-regression.ipynb](./05-linear-regression/linear-regression.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-09 Wed] </span></span> Intermediate sklearn [./06-intermediate-sklearn/intermediate-sklearn.ipynb](./06-intermediate-sklearn/intermediate-sklearn.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-14 Mon] </span></span> interactive project day (Happy Valentine's Day!)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-16 Wed] </span></span> nonlinear sklearn [./07-nonlinear-sklearn/nonlinear-sklearn.ipynb](./07-nonlinear-sklearn/nonlinear-sklearn.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-21 Mon] </span></span> random forests [./08-random-forests/random-forests.ipynb](./08-random-forests/random-forests.ipynb)

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-23 Wed] </span></span> presentations

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-02-28 Mon] </span></span> presentations

# %% [markdown]
# ## <span class="timestamp-wrapper"><span class="timestamp">[2022-03-02 Wed] </span></span> presentations
